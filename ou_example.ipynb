# %%
import jax
import flax
import jax.random as random
import flax.linen as nn
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
from nde.density_estimator import DensityEstimator
from simulators.ou_simulator import OUSim

print('Jax version', jax.__version__)
print('Flax version', flax.__version__)
# Out:
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Jax version 0.4.8
# Flax version 0.5.3

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Introduction
#
# We are interested in carrying out Bayesian parameter inference of a stochastic dynamical system $\mathcal{M}_{\theta}$, parametrised by $\theta$. For example $\mathcal{M}_{\theta}$ can be a jump process or a diffusion process.
#
# So, lets assume we have some noisy time-series data $Y=(y_1,\ldots, y_T)$, observed at $T$ experimental time points, and we assume that these data are explained by $\mathcal{M}_{\theta}$. In a Bayesian framework we can place some prior $p(\theta)$ on the parameters and then write the posterior as:
#
# $p(\theta|Y) \propto p(\theta)p(Y|\theta)$.
#
# For many interesting stochastic systems $p(Y|\theta)$ is intractable and thus likelihood-free inference is required.

# %% [markdown]
# # Neural Likelihood-free inference (NLFI)
#
# Recently, a series of papers have jointly popularised the idea of using a normalising-flow to carry out LFI. The basic idea is as follows:
#
# - Simulate pairs of $\theta, Y$ from their joint distribution and create a training dataset, of $N$ samples $\{\theta^n,Y^n\}_{n=1}^N$.
# - Train a conditional density estimator (a normalising-flow) $q_{\psi}(\theta|s(Y))$ using this training dataset, where $s(Y)$ is a summary of $Y$.
# - The trained density estimator then becomes an approximation to the posterior $p(\theta|Y)\approx q_{\psi}(\theta|s(Y))$.
# -  Draw samples $\theta \sim q_{\psi}(\theta|s(Y_o))$ by conditioning on a particular dataset $Y_o$.

# %% [markdown]
# # Working example: The Ornstein–Uhlenbeck diffusion process
#
# The dynamics of OU process is given by a linear SDE and thus has a tractable transition density. Strictly speaking we don't need LFI here. However, this is a simple enough model to illustrate the basics of NLFI and thus I have chosen it. Besides, the OU process had been used in numerous benchmarking studies related to inference of stochastic processes. The OU process is given by the following linear SDE:
# $dx_t = c_1(c_2 -x_t)dt + c_3 dw_t$,
#
# with parameters: $\theta=(c_1,c_2,c_3)$.
# Lets generate some fake data using the simulator class we have defined for this model

# %%
simulator = OUSim(simulate_summary=False)
true_param = np.array([[0.1, .5, 0.01],[0.1, .5, 0.01]])
fake_data  = simulator(true_param)
# Out:
# Simulation started
# Simulation Finished

# %%
sns.set_context("paper", font_scale=1)
sns.set(rc={"figure.figsize":(15, 7),"font.size":20,"axes.titlesize":20,"axes.labelsize":16,"axes.linewidth":1,
    "xtick.labelsize":16, "ytick.labelsize":16},style="white")
times = np.arange(0,10,.1)


plt.plot(times,fake_data.squeeze()[0,:],color='brown', lw=2)
plt.plot(times,fake_data.squeeze()[1,:],color='blue', lw=2)
plt.ylabel(r"$x_t$", fontsize=20)
plt.xlabel('times', fontsize=20)
plt.xlim([0,10])
# Out:
# (0.0, 10.0)

# %% [markdown]
# ## Training a flow on simulated dataset
#
# Now lets generate a large enough training set using this simulator and train a normalising-flow. We have implemented a coupling based flow architecture (basically a modification of real-NVP flow) that was used in [here](https://arxiv.org/pdf/2003.06281.pdf). However, before we invoke training we need to do two more things:
# - Set priors: a function that simulates $N$ samples from $p(\theta)$.

# %%
def priors(N):
  p_samples = np.random.gamma(2,1/2,size=(N, 3))
  
  return p_samples.astype(np.float32)

# %% [markdown]
# - Set summary statistics. Rather than handcrafting such summaries, we are going learn the summary by using a summariser neural network. We will use a LSTM.

# %%
class SummariserLSTM(nn.Module):
  features: int
  @nn.compact
  def __call__(self, x):
    batch_size = x.shape[0]
    cell = nn.LSTMCell()
    def body_fn(cell, carry, x):
      carry, y = cell(carry, x)
      return carry, y

    scan = nn.scan(
      body_fn, variable_broadcast="params",
      split_rngs={"params": False}, in_axes=1, out_axes=1)

    carry = nn.LSTMCell.initialize_carry(random.PRNGKey(20), \
                                (batch_size,), self.features)

    carry, x = scan(cell, carry, x)
    x = nn.Dense(self.features,kernel_init=nn.initializers.glorot_uniform(),
                            bias_init=nn.initializers.zeros)(x)
    x = nn.relu(x)

    return x[...,-1,:]
summariser = SummariserLSTM(20)

# %% [markdown]
# We can now go ahead and train all the neural networks: 1) the normalising-flow based conditional density estimator and 2) the LSTM summariser
#
# we set the total number of simulations `n_sim=25000`

# %%
network_settings ={
    'hidden_features': [64, 64, 64],
    'n_blocks': 4}

estimator = DensityEstimator(simulator, priors, network_settings, summariser=summariser)

# %%
trained_network, trained_weights = estimator.train(n_sim=25000)
# Out:
# Simulation started
# Simulation Finished
# Simulation started
# Simulation Finished
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/lift.py:112: FutureWarning: jax.tree_flatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_flatten instead.
#   scopes, treedef = jax.tree_flatten(scope_tree)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/lift.py:723: FutureWarning: jax.tree_leaves is deprecated, and will be removed in a future release. Use jax.tree_util.tree_leaves instead.
#   leaves = jax.tree_leaves(x)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/lift.py:729: FutureWarning: jax.tree_leaves is deprecated, and will be removed in a future release. Use jax.tree_util.tree_leaves instead.
#   lengths = set(jax.tree_leaves(lengths))
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/axes_scan.py:134: FutureWarning: jax.tree_flatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_flatten instead.
#   in_avals, in_tree = jax.tree_flatten(input_avals)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/linen/transforms.py:249: FutureWarning: jax.tree_leaves is deprecated, and will be removed in a future release. Use jax.tree_util.tree_leaves instead.
#   jax.tree_leaves(tree)))
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/axes_scan.py:146: FutureWarning: jax.tree_unflatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_unflatten instead.
#   broadcast_in, constants_out = jax.tree_unflatten(out_tree(), out_flat)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/optim/base.py:49: DeprecationWarning: Use `optax` instead of `flax.optim`. Refer to the update guide https://flax.readthedocs.io/en/latest/howtos/optax_update_guide.html for detailed instructions.
#   warnings.warn(
# Training epoch 1:   0%|          | 0/98 [00:00<?, ?it/s]/home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/optim/base.py:90: FutureWarning: jax.tree_flatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_flatten instead.
#   params_flat, treedef = jax.tree_flatten(params)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/optim/base.py:97: FutureWarning: jax.tree_unflatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_unflatten instead.
#   new_params = jax.tree_unflatten(treedef, new_params_flat)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/optim/base.py:98: FutureWarning: jax.tree_unflatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_unflatten instead.
#   new_param_states = jax.tree_unflatten(treedef, new_states_flat)
# Training epoch 1: 100%|██████████| 98/98 [00:35<00:00,  2.74it/s, Epoch 1,Batch 98,Loss: -0.389,Running Loss: 0.498]
# Training epoch 2: 100%|██████████| 98/98 [00:04<00:00, 21.26it/s, Epoch 2,Batch 98,Loss: -0.534,Running Loss: -0.637]
# Training epoch 3: 100%|██████████| 98/98 [00:04<00:00, 21.21it/s, Epoch 3,Batch 98,Loss: -1.399,Running Loss: -1.113]
# Training epoch 4: 100%|██████████| 98/98 [00:04<00:00, 21.32it/s, Epoch 4,Batch 98,Loss: -1.790,Running Loss: -1.441]
# Training epoch 5: 100%|██████████| 98/98 [00:04<00:00, 21.18it/s, Epoch 5,Batch 98,Loss: -1.894,Running Loss: -1.658]
# Training epoch 6: 100%|██████████| 98/98 [00:04<00:00, 21.21it/s, Epoch 6,Batch 98,Loss: -1.883,Running Loss: -1.762]
# Training epoch 7: 100%|██████████| 98/98 [00:04<00:00, 21.38it/s, Epoch 7,Batch 98,Loss: -1.621,Running Loss: -1.842]
# Training epoch 8: 100%|██████████| 98/98 [00:04<00:00, 21.24it/s, Epoch 8,Batch 98,Loss: -2.016,Running Loss: -1.925]
# Training epoch 9: 100%|██████████| 98/98 [00:04<00:00, 21.24it/s, Epoch 9,Batch 98,Loss: -2.362,Running Loss: -1.966]
# Training epoch 10: 100%|██████████| 98/98 [00:04<00:00, 20.49it/s, Epoch 10,Batch 98,Loss: -1.917,Running Loss: -2.025]
# Training epoch 11: 100%|██████████| 98/98 [00:04<00:00, 21.52it/s, Epoch 11,Batch 98,Loss: -1.880,Running Loss: -2.070]
# Training epoch 12: 100%|██████████| 98/98 [00:04<00:00, 21.28it/s, Epoch 12,Batch 98,Loss: -2.197,Running Loss: -2.123]
# Training epoch 13: 100%|██████████| 98/98 [00:04<00:00, 21.39it/s, Epoch 13,Batch 98,Loss: -1.986,Running Loss: -2.147]
# Training epoch 14: 100%|██████████| 98/98 [00:04<00:00, 21.52it/s, Epoch 14,Batch 98,Loss: -2.213,Running Loss: -2.182]
# Training epoch 15: 100%|██████████| 98/98 [00:04<00:00, 21.44it/s, Epoch 15,Batch 98,Loss: -2.395,Running Loss: -2.230]
# Training epoch 16: 100%|██████████| 98/98 [00:04<00:00, 21.26it/s, Epoch 16,Batch 98,Loss: -2.213,Running Loss: -2.260]
# Training epoch 17: 100%|██████████| 98/98 [00:04<00:00, 20.55it/s, Epoch 17,Batch 98,Loss: -2.301,Running Loss: -2.275]
# Training epoch 18: 100%|██████████| 98/98 [00:04<00:00, 20.39it/s, Epoch 18,Batch 98,Loss: -2.114,Running Loss: -2.285]
# Training epoch 19: 100%|██████████| 98/98 [00:04<00:00, 21.22it/s, Epoch 19,Batch 98,Loss: -2.254,Running Loss: -2.310]
# Training epoch 20: 100%|██████████| 98/98 [00:04<00:00, 21.08it/s, Epoch 20,Batch 98,Loss: -2.175,Running Loss: -2.329]
# Training epoch 21: 100%|██████████| 98/98 [00:04<00:00, 20.60it/s, Epoch 21,Batch 98,Loss: -2.063,Running Loss: -2.323]
# Training epoch 22: 100%|██████████| 98/98 [00:04<00:00, 19.82it/s, Epoch 22,Batch 98,Loss: -2.191,Running Loss: -2.355]
# Training epoch 23: 100%|██████████| 98/98 [00:04<00:00, 20.19it/s, Epoch 23,Batch 98,Loss: -2.528,Running Loss: -2.389]
# Training epoch 24: 100%|██████████| 98/98 [00:04<00:00, 20.52it/s, Epoch 24,Batch 98,Loss: -2.330,Running Loss: -2.372]
# Training epoch 25: 100%|██████████| 98/98 [00:04<00:00, 20.76it/s, Epoch 25,Batch 98,Loss: -2.216,Running Loss: -2.396]
# Training epoch 26: 100%|██████████| 98/98 [00:04<00:00, 20.43it/s, Epoch 26,Batch 98,Loss: -2.422,Running Loss: -2.422]
# Training epoch 27: 100%|██████████| 98/98 [00:04<00:00, 20.66it/s, Epoch 27,Batch 98,Loss: -2.405,Running Loss: -2.439]
# Training epoch 28: 100%|██████████| 98/98 [00:04<00:00, 20.55it/s, Epoch 28,Batch 98,Loss: -2.484,Running Loss: -2.439]
# Training epoch 29: 100%|██████████| 98/98 [00:04<00:00, 20.85it/s, Epoch 29,Batch 98,Loss: -2.456,Running Loss: -2.417]
# Training epoch 30: 100%|██████████| 98/98 [00:04<00:00, 20.54it/s, Epoch 30,Batch 98,Loss: -2.479,Running Loss: -2.446]
# Training epoch 31: 100%|██████████| 98/98 [00:04<00:00, 20.57it/s, Epoch 31,Batch 98,Loss: -2.593,Running Loss: -2.475]
# Training epoch 32: 100%|██████████| 98/98 [00:05<00:00, 19.29it/s, Epoch 32,Batch 98,Loss: -2.408,Running Loss: -2.469]
# Training epoch 33: 100%|██████████| 98/98 [00:04<00:00, 20.61it/s, Epoch 33,Batch 98,Loss: -2.599,Running Loss: -2.502]
# Training epoch 34: 100%|██████████| 98/98 [00:04<00:00, 19.86it/s, Epoch 34,Batch 98,Loss: -2.632,Running Loss: -2.478]
# Training epoch 35: 100%|██████████| 98/98 [00:04<00:00, 20.53it/s, Epoch 35,Batch 98,Loss: -2.613,Running Loss: -2.477]
# Training epoch 36: 100%|██████████| 98/98 [00:04<00:00, 20.53it/s, Epoch 36,Batch 98,Loss: -2.398,Running Loss: -2.519]
# Training epoch 37: 100%|██████████| 98/98 [00:04<00:00, 20.70it/s, Epoch 37,Batch 98,Loss: -2.478,Running Loss: -2.511]
# Training epoch 38: 100%|██████████| 98/98 [00:04<00:00, 20.65it/s, Epoch 38,Batch 98,Loss: -2.480,Running Loss: -2.515]
# Training epoch 39: 100%|██████████| 98/98 [00:05<00:00, 18.87it/s, Epoch 39,Batch 98,Loss: -2.592,Running Loss: -2.519]
# Training epoch 40: 100%|██████████| 98/98 [00:04<00:00, 19.72it/s, Epoch 40,Batch 98,Loss: -2.513,Running Loss: -2.520]
# Training epoch 41: 100%|██████████| 98/98 [00:04<00:00, 20.44it/s, Epoch 41,Batch 98,Loss: -2.411,Running Loss: -2.524]
# Training epoch 42: 100%|██████████| 98/98 [00:04<00:00, 20.65it/s, Epoch 42,Batch 98,Loss: -2.397,Running Loss: -2.533]
# Training epoch 43: 100%|██████████| 98/98 [00:04<00:00, 20.48it/s, Epoch 43,Batch 98,Loss: -2.541,Running Loss: -2.525]
# Training epoch 44: 100%|██████████| 98/98 [00:04<00:00, 20.68it/s, Epoch 44,Batch 98,Loss: -2.748,Running Loss: -2.526]
# Training epoch 45: 100%|██████████| 98/98 [00:04<00:00, 20.66it/s, Epoch 45,Batch 98,Loss: -2.507,Running Loss: -2.541]
# Training epoch 46: 100%|██████████| 98/98 [00:04<00:00, 20.00it/s, Epoch 46,Batch 98,Loss: -2.488,Running Loss: -2.561]
# Training epoch 47: 100%|██████████| 98/98 [00:04<00:00, 20.80it/s, Epoch 47,Batch 98,Loss: -2.596,Running Loss: -2.562]
# Density Estimator Converged

# %% [markdown]
# ## Sampling from posterior
#
# We are basically done! We have an approximation  $p(\theta|Y)\approx q_{\psi}(\theta|s(Y))$, with $s(Y)=LSTM(Y)$, from which we can draw samples by conditioning with the actual observed data $Y_o$. In our case that is the `fake_data` we have prviosuly generated.

# %%
nlfi_params = estimator.posterior_samples(random.PRNGKey(1), fake_data, trained_network, trained_weights, n_samples=1000)

# %% [markdown]
# Finally some marginal posterior plots...

# %%
param_names = [r"$c_1$",r"$c_2$", r"$c_3$"]
real_params = np.array([0.1, .5, 0.01])
plt.figure(figsize=(15,5))
for i, p in enumerate(param_names):        
        
        plt.subplot(1, 3, i+1)
        plt.axvline(real_params[i], linewidth=2.5, color='black')
        if i==0:

                sns.kdeplot(nlfi_params[:, 0, i], color='green', linewidth = 2.5)
                plt.ylabel('Frequency')
                plt.xlabel(param_names[i]) 
        else:
                sns.kdeplot(nlfi_params[:, 0, i], linewidth = 2.5, color='green') 

                plt.ylabel('Frequency')
                plt.xlabel(param_names[i])        
                
plt.subplots_adjust(hspace=0.7)
plt.tight_layout()
plt.show()
