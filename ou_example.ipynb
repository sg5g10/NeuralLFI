# %%
import jax
import flax
import jax.random as random
import flax.linen as nn
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
from nde.density_estimator import DensityEstimator
from simulators.ou_simulator import OUSim

print('Jax version', jax.__version__)
print('Flax version', flax.__version__)
# Out:
# Jax version 0.4.8
# Flax version 0.5.3

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Introduction
#
# We are interested in carrying out Bayesian parameter inference of a stochastic dynamical system $\mathcal{M}_{\theta}$, parametrised by $\theta$. In particular, I am considering stochastic reaction networks that are modelled as a Markov jump process (MJP). Thus,  $\theta$ here describes the reaction rates.
#
# So, lets assume we have some noisy time-series data $Y=(y_1,\ldots, y_T)$, observed at $T$ experimental time points, and we assume that these data are explained by a MJP $\mathcal{M}_{\theta}$. In a Bayesian framework we can place some prior $p(\theta)$ on the parameters and then write the posterior as:
#
# $p(\theta|Y) \propto p(\theta)p(Y|\theta)$.
#
# For MJPs (and many other interesting stochastic systems) $p(Y|\theta)$ is intractable and thus likelihood-free inference is required.

# %% [markdown]
# # Neural Likelihood-free inference
#
# Recently, a series of papers have jointly popularised the idea of using a normalising-flow to carry out LFI. The basic idea is as follows:
#
# - Simulate pairs of $\theta, Y$ from their joint distribution and create a training dataset, of $N$ samples $\{\theta^n,Y^n\}_{n=1}^N$.
# - Train a conditional density estimator (a normalising-flow) $q_{\psi}(\theta|s(Y))$ using this training dataset, where $s(Y)$ is a summary of $Y$.
# - The trained density estimator then becomes an approximation to the posterior $p(\theta|Y)\approx q_{\psi}(\theta|s(Y))$.
# -  Draw samples $\theta \sim q_{\psi}(\theta|s(Y_o))$ by conditioning on a particular dataset $Y_o$.

# %% [markdown]
# # Working example: The Ornstein–Uhlenbeck diffusion process
#
# The OU process is linear SDE and thus has a tractable transition density. Strictly speaking we don't need LFI here. However, this is a simple enough model to illustrate the basics of NLFI and thus I have chosen it. Besides, the OU process had been used in numerous benchmarking studies related to inference of stochastic processes. The OU process is given by the following linear SDE:
# $dx_t = c_1(c_2 -x_t)dt + c_3 dw_t$,
#
# with parameters: $\theta=(c_1,c_2,c_3)$.
# Lets generate some fake data using the simulator class we have defined for this model

# %%
simulator = OUSim(simulate_summary=False)
true_param = np.array([[0.1, .5, 0.01],[0.1, .5, 0.01]])
fake_data  = simulator(true_param)
# Out:
# Simulation started
# Simulation Finished
# (100,)

# %%
sns.set_context("paper", font_scale=1)
sns.set(rc={"figure.figsize":(15, 7),"font.size":20,"axes.titlesize":20,"axes.labelsize":16,"axes.linewidth":1,
    "xtick.labelsize":16, "ytick.labelsize":16},style="white")
times = np.arange(0,10,.1)


plt.plot(times,fake_data.squeeze()[0,:],color='brown', lw=2)
plt.plot(times,fake_data.squeeze()[1,:],color='blue', lw=2)
plt.ylabel(r"$x_t$", fontsize=20)
plt.xlabel('times', fontsize=20)
plt.xlim([0,10])
# Out:
# (0.0, 10.0)

# %% [markdown]
# ## Training a flow on simulated dataset
#
# Now lets generate a large enough training set using this simulator and train a normalising-flow. We have implemented a coupling based flow architecture (basically a modification of real-NVP flow) that was used in [here](https://arxiv.org/pdf/2003.06281.pdf). However, before we invoke training we need to do two more things:
# - Set priors: a function that simulates $N$ samples from $p(\theta)$.

# %%
def priors(N):
  p_samples = np.random.gamma(2,1/2,size=(N, 3))
  
  return p_samples.astype(np.float32)

# %% [markdown]
# - Set summary statistics. Rather than handcrafting such summaries, we are going learn the summary by using a summariser neural network. We will use a LSTM.

# %%
class SummariserLSTM(nn.Module):
  features: int
  @nn.compact
  def __call__(self, x):
    batch_size = x.shape[0]
    cell = nn.LSTMCell()
    def body_fn(cell, carry, x):
      carry, y = cell(carry, x)
      return carry, y

    scan = nn.scan(
      body_fn, variable_broadcast="params",
      split_rngs={"params": False}, in_axes=1, out_axes=1)

    carry = nn.LSTMCell.initialize_carry(random.PRNGKey(20), \
                                (batch_size,), self.features)

    carry, x = scan(cell, carry, x)
    x = nn.Dense(self.features,kernel_init=nn.initializers.glorot_uniform(),
                            bias_init=nn.initializers.zeros)(x)
    x = nn.relu(x)

    return x[...,-1,:]
summariser = SummariserLSTM(20)

# %% [markdown]
# We can now go ahead and train all the neural networks: 1) the normalising-flow based conditional density estimator and 2) the LSTM summariser
#
# we set the total number of simulations `n_sim=50000`

# %%
network_settings ={
    'hidden_features': [64, 64, 64, 64],
    'n_blocks': 5}

estimator = DensityEstimator(simulator, priors, network_settings, summariser=summariser)

# %%
trained_network, trained_weights = estimator.train(n_sim=50000)
# Out:
# Simulation started
# Simulation Finished
# Simulation started
# Simulation Finished
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/lift.py:112: FutureWarning: jax.tree_flatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_flatten instead.
#   scopes, treedef = jax.tree_flatten(scope_tree)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/lift.py:723: FutureWarning: jax.tree_leaves is deprecated, and will be removed in a future release. Use jax.tree_util.tree_leaves instead.
#   leaves = jax.tree_leaves(x)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/lift.py:729: FutureWarning: jax.tree_leaves is deprecated, and will be removed in a future release. Use jax.tree_util.tree_leaves instead.
#   lengths = set(jax.tree_leaves(lengths))
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/axes_scan.py:134: FutureWarning: jax.tree_flatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_flatten instead.
#   in_avals, in_tree = jax.tree_flatten(input_avals)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/linen/transforms.py:249: FutureWarning: jax.tree_leaves is deprecated, and will be removed in a future release. Use jax.tree_util.tree_leaves instead.
#   jax.tree_leaves(tree)))
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/core/axes_scan.py:146: FutureWarning: jax.tree_unflatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_unflatten instead.
#   broadcast_in, constants_out = jax.tree_unflatten(out_tree(), out_flat)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/optim/base.py:49: DeprecationWarning: Use `optax` instead of `flax.optim`. Refer to the update guide https://flax.readthedocs.io/en/latest/howtos/optax_update_guide.html for detailed instructions.
#   warnings.warn(
# Training epoch 1:   0%|          | 0/196 [00:00<?, ?it/s]/home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/optim/base.py:90: FutureWarning: jax.tree_flatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_flatten instead.
#   params_flat, treedef = jax.tree_flatten(params)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/optim/base.py:97: FutureWarning: jax.tree_unflatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_unflatten instead.
#   new_params = jax.tree_unflatten(treedef, new_params_flat)
# /home/sanmitra/anaconda3/envs/vbode/lib/python3.9/site-packages/flax/optim/base.py:98: FutureWarning: jax.tree_unflatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_unflatten instead.
#   new_param_states = jax.tree_unflatten(treedef, new_states_flat)
# Training epoch 1: 100%|██████████| 196/196 [01:21<00:00,  2.39it/s, Epoch 1,Batch 196,Loss: -1.146,Running Loss: -0.141]
# Training epoch 2: 100%|██████████| 196/196 [00:14<00:00, 13.39it/s, Epoch 2,Batch 196,Loss: -1.720,Running Loss: -1.346]
# Training epoch 3: 100%|██████████| 196/196 [00:12<00:00, 15.39it/s, Epoch 3,Batch 196,Loss: -1.921,Running Loss: -1.697]
# Training epoch 4: 100%|██████████| 196/196 [00:21<00:00,  9.06it/s, Epoch 4,Batch 196,Loss: -1.981,Running Loss: -1.837]
# Training epoch 5: 100%|██████████| 196/196 [00:23<00:00,  8.21it/s, Epoch 5,Batch 196,Loss: -1.910,Running Loss: -1.925]
# Training epoch 6: 100%|██████████| 196/196 [00:12<00:00, 15.24it/s, Epoch 6,Batch 196,Loss: -2.084,Running Loss: -1.994]
# Training epoch 7: 100%|██████████| 196/196 [00:16<00:00, 11.78it/s, Epoch 7,Batch 196,Loss: -2.100,Running Loss: -2.045]
# Training epoch 8: 100%|██████████| 196/196 [00:14<00:00, 13.09it/s, Epoch 8,Batch 196,Loss: -1.825,Running Loss: -2.068]
# Training epoch 9: 100%|██████████| 196/196 [00:17<00:00, 11.14it/s, Epoch 9,Batch 196,Loss: -1.895,Running Loss: -2.131]
# Training epoch 10: 100%|██████████| 196/196 [00:12<00:00, 16.02it/s, Epoch 10,Batch 196,Loss: -2.004,Running Loss: -2.176]
# Training epoch 11: 100%|██████████| 196/196 [00:13<00:00, 14.22it/s, Epoch 11,Batch 196,Loss: -2.235,Running Loss: -2.235]
# Training epoch 12: 100%|██████████| 196/196 [00:18<00:00, 10.68it/s, Epoch 12,Batch 196,Loss: -2.254,Running Loss: -2.276]
# Training epoch 13: 100%|██████████| 196/196 [00:20<00:00,  9.49it/s, Epoch 13,Batch 196,Loss: -2.380,Running Loss: -2.320]
# Training epoch 14: 100%|██████████| 196/196 [00:15<00:00, 12.79it/s, Epoch 14,Batch 196,Loss: -2.287,Running Loss: -2.348]
# Training epoch 15: 100%|██████████| 196/196 [00:22<00:00,  8.91it/s, Epoch 15,Batch 196,Loss: -2.095,Running Loss: -2.365]
# Training epoch 16: 100%|██████████| 196/196 [00:19<00:00,  9.86it/s, Epoch 16,Batch 196,Loss: -2.472,Running Loss: -2.384]
# Training epoch 17: 100%|██████████| 196/196 [00:12<00:00, 15.77it/s, Epoch 17,Batch 196,Loss: -2.304,Running Loss: -2.408]
# Training epoch 18: 100%|██████████| 196/196 [00:13<00:00, 14.71it/s, Epoch 18,Batch 196,Loss: -2.416,Running Loss: -2.427]
# Training epoch 19: 100%|██████████| 196/196 [00:15<00:00, 12.90it/s, Epoch 19,Batch 196,Loss: -2.883,Running Loss: -2.455]
# Training epoch 20: 100%|██████████| 196/196 [00:12<00:00, 16.01it/s, Epoch 20,Batch 196,Loss: -2.671,Running Loss: -2.480]
# Training epoch 21: 100%|██████████| 196/196 [00:38<00:00,  5.07it/s, Epoch 21,Batch 196,Loss: -2.486,Running Loss: -2.482]
# Training epoch 22: 100%|██████████| 196/196 [00:29<00:00,  6.71it/s, Epoch 22,Batch 196,Loss: -2.562,Running Loss: -2.508]
# Training epoch 23: 100%|██████████| 196/196 [00:28<00:00,  6.84it/s, Epoch 23,Batch 196,Loss: -2.534,Running Loss: -2.518]
# Training epoch 24: 100%|██████████| 196/196 [00:16<00:00, 11.94it/s, Epoch 24,Batch 196,Loss: -2.552,Running Loss: -2.527]
# Training epoch 25: 100%|██████████| 196/196 [01:16<00:00,  2.56it/s, Epoch 25,Batch 196,Loss: -2.427,Running Loss: -2.548]
# Training epoch 26: 100%|██████████| 196/196 [00:25<00:00,  7.61it/s, Epoch 26,Batch 196,Loss: -2.341,Running Loss: -2.566]
# Training epoch 27: 100%|██████████| 196/196 [00:12<00:00, 15.37it/s, Epoch 27,Batch 196,Loss: -2.705,Running Loss: -2.581]
# Training epoch 28: 100%|██████████| 196/196 [00:29<00:00,  6.69it/s, Epoch 28,Batch 196,Loss: -2.384,Running Loss: -2.602]
# Training epoch 29: 100%|██████████| 196/196 [00:16<00:00, 11.85it/s, Epoch 29,Batch 196,Loss: -2.727,Running Loss: -2.604]
# Training epoch 30: 100%|██████████| 196/196 [00:25<00:00,  7.60it/s, Epoch 30,Batch 196,Loss: -2.509,Running Loss: -2.598]
# Training epoch 31: 100%|██████████| 196/196 [00:15<00:00, 13.00it/s, Epoch 31,Batch 196,Loss: -2.780,Running Loss: -2.634]
# Training epoch 32: 100%|██████████| 196/196 [00:24<00:00,  8.11it/s, Epoch 32,Batch 196,Loss: -2.649,Running Loss: -2.650]
# Training epoch 33: 100%|██████████| 196/196 [00:14<00:00, 13.84it/s, Epoch 33,Batch 196,Loss: -2.296,Running Loss: -2.663]
# Training epoch 34: 100%|██████████| 196/196 [00:13<00:00, 14.93it/s, Epoch 34,Batch 196,Loss: -2.929,Running Loss: -2.683]
# Training epoch 35: 100%|██████████| 196/196 [00:15<00:00, 12.56it/s, Epoch 35,Batch 196,Loss: -2.420,Running Loss: -2.697]
# Training epoch 36: 100%|██████████| 196/196 [00:15<00:00, 12.55it/s, Epoch 36,Batch 196,Loss: -2.558,Running Loss: -2.723]
# Training epoch 37: 100%|██████████| 196/196 [00:27<00:00,  7.21it/s, Epoch 37,Batch 196,Loss: -2.945,Running Loss: -2.730]
# Training epoch 38: 100%|██████████| 196/196 [00:12<00:00, 15.13it/s, Epoch 38,Batch 196,Loss: -2.691,Running Loss: -2.743]
# Training epoch 39: 100%|██████████| 196/196 [00:17<00:00, 11.52it/s, Epoch 39,Batch 196,Loss: -2.781,Running Loss: -2.760]
# Training epoch 40: 100%|██████████| 196/196 [00:12<00:00, 16.32it/s, Epoch 40,Batch 196,Loss: -2.974,Running Loss: -2.766]
# Training epoch 41: 100%|██████████| 196/196 [00:15<00:00, 12.76it/s, Epoch 41,Batch 196,Loss: -3.045,Running Loss: -2.781]
# Training epoch 42: 100%|██████████| 196/196 [00:11<00:00, 16.70it/s, Epoch 42,Batch 196,Loss: -2.755,Running Loss: -2.791]
# Training epoch 43: 100%|██████████| 196/196 [00:11<00:00, 16.69it/s, Epoch 43,Batch 196,Loss: -2.925,Running Loss: -2.830]
# Training epoch 44: 100%|██████████| 196/196 [00:12<00:00, 16.19it/s, Epoch 44,Batch 196,Loss: -2.756,Running Loss: -2.849]
# Training epoch 45: 100%|██████████| 196/196 [00:12<00:00, 16.17it/s, Epoch 45,Batch 196,Loss: -2.601,Running Loss: -2.845]
# Training epoch 46: 100%|██████████| 196/196 [00:12<00:00, 16.12it/s, Epoch 46,Batch 196,Loss: -2.628,Running Loss: -2.848]
# Training epoch 47: 100%|██████████| 196/196 [00:15<00:00, 12.74it/s, Epoch 47,Batch 196,Loss: -3.165,Running Loss: -2.859]
# Training epoch 48: 100%|██████████| 196/196 [00:12<00:00, 16.22it/s, Epoch 48,Batch 196,Loss: -2.800,Running Loss: -2.884]
# Training epoch 49: 100%|██████████| 196/196 [00:11<00:00, 16.74it/s, Epoch 49,Batch 196,Loss: -2.784,Running Loss: -2.903]
# Training epoch 50: 100%|██████████| 196/196 [00:11<00:00, 16.34it/s, Epoch 50,Batch 196,Loss: -2.891,Running Loss: -2.905]
# Training epoch 51: 100%|██████████| 196/196 [00:12<00:00, 16.30it/s, Epoch 51,Batch 196,Loss: -3.088,Running Loss: -2.921]
# Training epoch 52: 100%|██████████| 196/196 [00:11<00:00, 16.72it/s, Epoch 52,Batch 196,Loss: -2.838,Running Loss: -2.894]
# Training epoch 53: 100%|██████████| 196/196 [00:12<00:00, 16.01it/s, Epoch 53,Batch 196,Loss: -2.969,Running Loss: -2.930]
# Training epoch 54: 100%|██████████| 196/196 [00:12<00:00, 15.33it/s, Epoch 54,Batch 196,Loss: -2.492,Running Loss: -2.926]
# Training epoch 55: 100%|██████████| 196/196 [00:12<00:00, 15.85it/s, Epoch 55,Batch 196,Loss: -2.855,Running Loss: -2.920]
# Training epoch 56: 100%|██████████| 196/196 [00:17<00:00, 11.34it/s, Epoch 56,Batch 196,Loss: -2.929,Running Loss: -2.939]
# Training epoch 57: 100%|██████████| 196/196 [00:14<00:00, 13.51it/s, Epoch 57,Batch 196,Loss: -3.451,Running Loss: -2.951]
# Training epoch 58: 100%|██████████| 196/196 [00:12<00:00, 15.28it/s, Epoch 58,Batch 196,Loss: -3.202,Running Loss: -2.963]
# Training epoch 59: 100%|██████████| 196/196 [00:17<00:00, 10.92it/s, Epoch 59,Batch 196,Loss: -2.686,Running Loss: -2.957]
# Training epoch 60: 100%|██████████| 196/196 [00:13<00:00, 14.93it/s, Epoch 60,Batch 196,Loss: -2.915,Running Loss: -2.988]
# Training epoch 61: 100%|██████████| 196/196 [00:17<00:00, 11.10it/s, Epoch 61,Batch 196,Loss: -2.807,Running Loss: -2.960]
# Training epoch 62: 100%|██████████| 196/196 [00:12<00:00, 16.01it/s, Epoch 62,Batch 196,Loss: -2.787,Running Loss: -2.965]
# Training epoch 63: 100%|██████████| 196/196 [00:12<00:00, 16.23it/s, Epoch 63,Batch 196,Loss: -2.818,Running Loss: -3.003]
# Training epoch 64: 100%|██████████| 196/196 [00:13<00:00, 14.80it/s, Epoch 64,Batch 196,Loss: -2.410,Running Loss: -2.977]
# Training epoch 65: 100%|██████████| 196/196 [00:11<00:00, 17.62it/s, Epoch 65,Batch 196,Loss: -2.996,Running Loss: -2.994]
# Training epoch 66: 100%|██████████| 196/196 [00:12<00:00, 16.29it/s, Epoch 66,Batch 196,Loss: -2.992,Running Loss: -2.976]
# Training epoch 67: 100%|██████████| 196/196 [00:12<00:00, 15.17it/s, Epoch 67,Batch 196,Loss: -2.974,Running Loss: -3.024]
# Training epoch 68: 100%|██████████| 196/196 [00:14<00:00, 13.15it/s, Epoch 68,Batch 196,Loss: -2.912,Running Loss: -3.011]
# Training epoch 69: 100%|██████████| 196/196 [00:11<00:00, 16.44it/s, Epoch 69,Batch 196,Loss: -2.837,Running Loss: -3.020]
# Training epoch 70: 100%|██████████| 196/196 [00:12<00:00, 15.90it/s, Epoch 70,Batch 196,Loss: -3.420,Running Loss: -3.024]
# Training epoch 71: 100%|██████████| 196/196 [00:12<00:00, 15.83it/s, Epoch 71,Batch 196,Loss: -3.220,Running Loss: -3.036]
# Training epoch 72: 100%|██████████| 196/196 [00:16<00:00, 12.15it/s, Epoch 72,Batch 196,Loss: -2.871,Running Loss: -3.010]
# Training epoch 73: 100%|██████████| 196/196 [00:12<00:00, 15.68it/s, Epoch 73,Batch 196,Loss: -3.144,Running Loss: -3.047]
# Training epoch 74: 100%|██████████| 196/196 [00:12<00:00, 15.98it/s, Epoch 74,Batch 196,Loss: -3.039,Running Loss: -3.028]
# Training epoch 75: 100%|██████████| 196/196 [00:12<00:00, 15.73it/s, Epoch 75,Batch 196,Loss: -2.752,Running Loss: -3.046]
# Density Estimator Converged

# %% [markdown]
# ## Sampling from posterior
#
# We are basically done! We have an approximation  $p(\theta|Y)\approx q_{\psi}(\theta|s(Y))$, with $s(Y)=LSTM(Y)$, from which we can draw samples by conditioning with the actual observed data $Y_o$. In our case that is the `fake_data` we have prviosuly generated.

# %%
nlfi_params = estimator.posterior_samples(random.PRNGKey(1), fake_data, trained_network, trained_weights, n_samples=1000)

# %% [markdown]
# Finally some marginal posterior plots...

# %%
param_names = [r"$c_1$",r"$c_2$", r"$c_3$"]
real_params = np.array([0.1, .5, 0.01])
plt.figure(figsize=(15,5))
for i, p in enumerate(param_names):        
        
        plt.subplot(1, 3, i+1)
        plt.axvline(real_params[i], linewidth=2.5, color='black')
        if i==0:

                sns.kdeplot(nlfi_params[:, 0, i], color='green', linewidth = 2.5)
                plt.ylabel('Frequency')
                plt.xlabel(param_names[i]) 
        else:
                sns.kdeplot(nlfi_params[:, 0, i], linewidth = 2.5, color='green') 

                plt.ylabel('Frequency')
                plt.xlabel(param_names[i])        
                
plt.subplots_adjust(hspace=0.7)
plt.tight_layout()
plt.show()
